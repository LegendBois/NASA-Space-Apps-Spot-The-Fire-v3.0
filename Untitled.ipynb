# %%
import pandas as pd

# %%
flames = pd.read_csv("Data/Today/MODIS_C6_Global_24h.csv")

# %%
flames
# Out:
#        latitude  longitude  brightness  scan  track    acq_date  acq_time  \
# 0       -17.964    -49.077       308.2   3.5    1.8  2020-10-01       120
# 1       -17.948    -49.079       306.3   3.5    1.8  2020-10-01       120
# 2       -17.434    -46.025       307.9   2.0    1.4  2020-10-01       120
# 3       -17.436    -46.044       314.3   2.0    1.4  2020-10-01       120
# 4       -17.497    -47.723       306.4   2.8    1.6  2020-10-01       120
# ...         ...        ...         ...   ...    ...         ...       ...
# 23220   -23.791    -64.542       301.4   3.2    1.7  2020-10-02       335
# 23221    -5.847    -35.469       303.7   2.3    1.5  2020-10-02       325
# 23222    -9.407    -40.389       303.5   4.8    2.0  2020-10-02       325
# 23223   -19.315    -41.583       309.4   3.7    1.8  2020-10-02       330
# 23224   -19.361    -41.522       303.2   3.7    1.8  2020-10-02       330
#
#       satellite  confidence version  bright_t31   frp daynight
# ...
